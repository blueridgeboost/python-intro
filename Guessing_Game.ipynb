# %% [markdown]
# # Guessing Game
#
# The program generates a random number between 1 and 100. The program asks the user to guess the number until the user guesses corectly. For each guess, the program prints a hint to tell the guesser the guess is too high or too low.
#
# The [Scratch program](https://scratch.mit.edu/projects/625805482/) is shown below.

# %% [markdown]
# ![guess-scratch.png](attachment:guess-scratch.png)

# %% [markdown]
# Let's try to understand this code and translate it in Python.
#
# To create a variable in Scratch:
# 1. Click ```Make a Variable```
# 1. Type the variable name, ```number```
# 1. Click ```OK```
#
# ![variable.png](data:image/png;base64,...)
#
# In Python, we do not need to declare a variable. It is sufficient to assign a value to it.

# %% [markdown]
# In Scratch, we assign a value to a variable using the ```set``` block.
# ![set.png](data:image/png;base64,...)
#
# In Python, we write ```number = 0```.

# %% [markdown]
# In Scratch, we use the ```pick random``` operator to generate a random number between 1 and 100. ![random.png](data:image/png;base64,...)
#
# We connect the two blocks to set the ```number``` variable to a number between 1 and 100. ![set-random.png](data:image/png;base64,...)
#
# The Python code that declares and sets a variable named ```number``` to a random number between 1 and 100 (inclusive) is shown below.

# %%
# We have to tell Python we use the random library
import random

number = random.randint(1, 101)

# %% [markdown]
# The ```forever``` block is written in Python as ```while(True):```
#
# First, we write the code block inside the loop and, next, we put the loop and the code block together.

# %% [markdown]
# ![ask.png](data:image/png;base64,...)
#
# The ```ask``` block does several actions.
# 1. Prints a bubble with the message
# 2. Displays a box for the user to enter text
# 3. Stores the value introduced by the user in a special variable called ```answer```.

# %% [markdown]
# In Python, we achive the same by using the ```input``` function.

# %%
answer = int(input("What number am I thinking of?"))

# %% [markdown]
# ![if.png](data:image/png;base64,...)

# %% [markdown]
# The ```if-then``` block above is written in Python as follows.

# %%
if (number == answer):
  print("Well done! You guessed my number!")
  exit(0)

# %% [markdown]
# Let's try to put together what we have and work to finish the program.
# ![guess-scratch.png](attachment:guess-scratch.png)

# %%
import random
number = random.randint(1, 101)

while(True):
    answer = int(input("What number am I thinking of?"))
    if (True):
        # TODO: write the if statement that prints Too low!
    elif (True):
        # TODO: write the if statement that prints Too high!
    else:
        print("Well done! You guessed my number!")
        break

# %% [markdown]
# ## Homework
#
# 1. In the Scratch program, add a variable named ```counter```. Add ```1``` to this variable every time the user guesses a number and modify the final message "Well done! You guessed my number!" to be "You guessed my number in X tries!", where X is the actual value of the variable ```counter```.
#
# 1. Modify the Python code above to have the same behavior as the modified Scratch program.
